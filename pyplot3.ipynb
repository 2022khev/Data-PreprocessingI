# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ent_arr = np.array([
    'Australia','Brazil','Canada','Chile','France','Germany','Greece','Iceland','India','Iran','Italy','Mexico','New Zealand',
    'Nigeria','Norway','Pakistan','Peru','Russia','Saudi Arabia','Singapore',
    'South Africa','Spain','sweden','turkey','UK','US'])
dr_arr = np.array([1.8,53,24.5,56.5,45.4,11.2,2.2,2.8,4,24.6,58.6,46.3,0.5,0.5,4.9,2.9,83.3,11,10,.4,0.5,21.5,61.6,
                  56.9,62.4,52.9])

test_arr = np.array([110,7197,600,1862,1636,1103,3510,1658,1226,2490,8243,4139,1101,4447,1443,280,2830,1602,4447,
                    1443,280,2830,1602,1205,1546,24988])

cc_arr =  np.array([24236,3456652,125408,390037,256534,229706,7684,2035,2836925,150279,255278,537031,1654,50488,10162,
                   290445,549321,935066,302686,56031,596060,370868,85411,253108,323008,5529824])

cc_arr_am = cc_arr/1000
color_arr = np.random.rand(26)
plt.title('Death Rate Per 100k vs. Confirmed Cases')
plt.xlabel("Death rate per 100k")
plt.ylabel("Confirmed Cases")
plt.scatter(dr_arr,test_arr, s= cc_arr_am,c=color_arr,alpha=0.5)

# %%
x1= [89,43,36,36,95,10,66,34,38,20]
y1=[21,46,3,35,67,95,53,72,58,10]

x2 = [26,29,48,64,6,5,36,66,72,40]
y2 = [26,34,99,33,38,20,56,2,47,15]

plt.scatter(x1,y1,c='pink',
                  linewidths=2,
                  marker = 's',
                  edgecolor='green',
                  s=50)
plt.scatter(x2,y2,c='yellow',
                  linewidths=2,
                  marker = '^',
                  edgecolor='red',
                  s=200)
plt.xlabel('X-axis')
plt.xlabel('Y-axis')
plt.show()

# %%
from mpl_toolkits import mplot3d

# %%
fig_9 = plt.figure(figsize =(8,5),dpi=100)
axes_9 = fig_9.add_axes([0.1,0.1,0.9,0.9],projection='3d')

z_3 = 15 * np.random.random(100)
x_3 = np.sin(z_3) * np.random.randn(100)
y_3 = np.cos(z_3) * np.random.randn(100)
axes_9.scatter3D(x_3,y_3,z_3,c=z_3,cmap='Blues');

# %%
z_3 = 15 * np.random.random(100)
x_3 = np.sin(z_3) * np.random.randn(100)
y_3 = np.cos(z_3) * np.random.randn(100)


def get_z(x,y):
    return np.sin(np.sqrt(x**2 + y**2))

x_4 = np.linspace(-6,6,30)
y_4 = np.linspace(-6,6,30)

x_4,y_4 = np.meshgrid(x_4,y_4)
z_4 = get_z(x_4,y_4)

axes_9.view_init(45,55)
axes_9.contour3D(x_4,y_4,z_4,80,cmap='Blues')

# %%
# pip install mpl_finance

# %%
# pip install --uprgrade mplfinance

# %%
import mplfinance as mpf

# %%
import random
df = pd.DataFrame([
              np.random.randint(5000,size=(731)),
              np.random.randint(5000,size=(731)),
              np.random.randint(5000,size=(731)),
              np.random.randint(5000,size=(731)),
             np.random.randint(5000,size=(731)),
                np.random.randint(5000,size=(731))
]).transpose()
Date = pd.date_range(start ='2020-5-20',end= '2022-5-20',freq='D')
df['Date'] = Date
df = df.rename({0:'Open',1:'High',2:'Low',3:'Close',4:'Adj Close',5:'Volume'},axis=1)
df = df.head(90)

# %%
data = df.to_numpy()
data
# Out:
# array([[4460, 3719, 3527, 228, 2003, 4621,
#         Timestamp('2020-05-20 00:00:00')],
#        [2246, 3718, 3409, 3455, 678, 2389,
#         Timestamp('2020-05-21 00:00:00')],
#        [4434, 3292, 1851, 1717, 2581, 1323,
#         Timestamp('2020-05-22 00:00:00')],
#        [2325, 3077, 3373, 3452, 4729, 4021,
#         Timestamp('2020-05-23 00:00:00')],
#        [189, 669, 4549, 3411, 442, 3681,
#         Timestamp('2020-05-24 00:00:00')],
#        [296, 3794, 3258, 54, 1490, 3467,
#         Timestamp('2020-05-25 00:00:00')],
#        [3847, 4699, 698, 381, 2486, 1140,
#         Timestamp('2020-05-26 00:00:00')],
#        [1304, 1953, 567, 241, 4754, 394,
#         Timestamp('2020-05-27 00:00:00')],
#        [695, 3541, 3748, 2267, 1675, 4482,
#         Timestamp('2020-05-28 00:00:00')],
#        [1655, 2910, 709, 2375, 3681, 2909,
#         Timestamp('2020-05-29 00:00:00')],
#        [3368, 2891, 586, 1455, 535, 2783,
#         Timestamp('2020-05-30 00:00:00')],
#        [4514, 512, 2237, 3621, 704, 2422,
#         Timestamp('2020-05-31 00:00:00')],
#        [4774, 3535, 3489, 2375, 3134, 3489,
#         Timestamp('2020-06-01 00:00:00')],
#        [569, 427, 4568, 2541, 1119, 2650,
#         Timestamp('2020-06-02 00:00:00')],
#        [4866, 2599, 3666, 555, 721, 4922,
#         Timestamp('2020-06-03 00:00:00')],
#        [4106, 72, 2230, 3881, 2812, 4169,
#         Timestamp('2020-06-04 00:00:00')],
#        [4765, 3274, 2278, 3874, 735, 998,
#         Timestamp('2020-06-05 00:00:00')],
#        [241, 2297, 4333, 831, 3566, 2355,
#         Timestamp('2020-06-06 00:00:00')],
#        [4721, 1186, 2023, 3387, 606, 3409,
#         Timestamp('2020-06-07 00:00:00')],
#        [3576, 4388, 4748, 3415, 3987, 592,
#         Timestamp('2020-06-08 00:00:00')],
#        [232, 1668, 1161, 242, 3660, 3777,
#         Timestamp('2020-06-09 00:00:00')],
#        [3899, 4933, 1010, 817, 3960, 343,
#         Timestamp('2020-06-10 00:00:00')],
#        [2539, 858, 1360, 4285, 3382, 727,
#         Timestamp('2020-06-11 00:00:00')],
#        [3979, 4327, 2909, 3157, 4641, 509,
#         Timestamp('2020-06-12 00:00:00')],
#        [1391, 2418, 2117, 645, 2299, 3314,
#         Timestamp('2020-06-13 00:00:00')],
#        [1388, 3865, 2857, 2208, 1978, 4342,
#         Timestamp('2020-06-14 00:00:00')],
#        [955, 1198, 381, 4225, 2422, 3213,
#         Timestamp('2020-06-15 00:00:00')],
#        [4821, 3428, 3546, 2169, 1466, 2573,
#         Timestamp('2020-06-16 00:00:00')],
#        [2543, 1206, 477, 841, 3234, 2967,
#         Timestamp('2020-06-17 00:00:00')],
#        [699, 4412, 2943, 124, 156, 4228,
#         Timestamp('2020-06-18 00:00:00')],
#        [4167, 4147, 1177, 1784, 2456, 1432,
#         Timestamp('2020-06-19 00:00:00')],
#        [2176, 1082, 1539, 274, 370, 4121,
#         Timestamp('2020-06-20 00:00:00')],
#        [1802, 643, 2490, 200, 1646, 4066,
#         Timestamp('2020-06-21 00:00:00')],
#        [4791, 2673, 2738, 4353, 2220, 1848,
#         Timestamp('2020-06-22 00:00:00')],
#        [14, 1561, 3523, 227, 1509, 724, Timestamp('2020-06-23 00:00:00')],
#        [2080, 2357, 1758, 3308, 2463, 4262,
#         Timestamp('2020-06-24 00:00:00')],
#        [1640, 4223, 2777, 4256, 3382, 3645,
#         Timestamp('2020-06-25 00:00:00')],
#        [2347, 4429, 3793, 1956, 4781, 1227,
#         Timestamp('2020-06-26 00:00:00')],
#        [1471, 3924, 380, 924, 4213, 409,
#         Timestamp('2020-06-27 00:00:00')],
#        [4567, 3613, 4915, 1659, 3621, 3377,
#         Timestamp('2020-06-28 00:00:00')],
#        [3151, 193, 1792, 1953, 193, 45, Timestamp('2020-06-29 00:00:00')],
#        [1706, 2798, 3556, 1082, 3017, 1313,
#         Timestamp('2020-06-30 00:00:00')],
#        [1655, 2043, 499, 236, 3206, 1312,
#         Timestamp('2020-07-01 00:00:00')],
#        [3498, 171, 966, 3022, 3964, 1796,
#         Timestamp('2020-07-02 00:00:00')],
#        [2465, 1432, 383, 3578, 1883, 615,
#         Timestamp('2020-07-03 00:00:00')],
#        [2698, 1450, 3612, 3753, 210, 3240,
#         Timestamp('2020-07-04 00:00:00')],
#        [945, 4289, 1081, 3672, 4537, 4953,
#         Timestamp('2020-07-05 00:00:00')],
#        [3872, 323, 4411, 1282, 3261, 4911,
#         Timestamp('2020-07-06 00:00:00')],
#        [761, 3992, 4494, 2536, 412, 4314,
#         Timestamp('2020-07-07 00:00:00')],
#        [4698, 2648, 4056, 218, 2827, 4244,
#         Timestamp('2020-07-08 00:00:00')],
#        [3615, 3971, 3387, 3086, 1082, 4160,
#         Timestamp('2020-07-09 00:00:00')],
#        [582, 2697, 227, 3177, 4025, 3307,
#         Timestamp('2020-07-10 00:00:00')],
#        [4244, 3711, 944, 1701, 4539, 1574,
#         Timestamp('2020-07-11 00:00:00')],
#        [816, 4155, 4496, 769, 1630, 2285,
#         Timestamp('2020-07-12 00:00:00')],
#        [4929, 4985, 3470, 2986, 2714, 1163,
#         Timestamp('2020-07-13 00:00:00')],
#        [2946, 1048, 1555, 98, 330, 4730,
#         Timestamp('2020-07-14 00:00:00')],
#        [2772, 1010, 399, 4673, 125, 3214,
#         Timestamp('2020-07-15 00:00:00')],
#        [1007, 1230, 4674, 1122, 289, 816,
#         Timestamp('2020-07-16 00:00:00')],
#        [1147, 3119, 1913, 2743, 3705, 3988,
#         Timestamp('2020-07-17 00:00:00')],
#        [487, 2045, 3807, 4939, 3700, 424,
#         Timestamp('2020-07-18 00:00:00')],
#        [4569, 988, 4868, 2434, 352, 3288,
#         Timestamp('2020-07-19 00:00:00')],
#        [1667, 3656, 3512, 1534, 4598, 3609,
#         Timestamp('2020-07-20 00:00:00')],
#        [4655, 1221, 750, 4819, 2790, 898,
#         Timestamp('2020-07-21 00:00:00')],
#        [2891, 212, 3176, 4444, 3216, 4410,
#         Timestamp('2020-07-22 00:00:00')],
#        [3520, 3069, 958, 4210, 1256, 2453,
#         Timestamp('2020-07-23 00:00:00')],
#        [2174, 2831, 3202, 3637, 1400, 2848,
#         Timestamp('2020-07-24 00:00:00')],
#        [4341, 1504, 203, 2310, 4090, 912,
#         Timestamp('2020-07-25 00:00:00')],
#        [3140, 1205, 4347, 4827, 4852, 3536,
#         Timestamp('2020-07-26 00:00:00')],
#        [4786, 3648, 3669, 3999, 4877, 1420,
#         Timestamp('2020-07-27 00:00:00')],
#        [228, 3089, 4188, 3791, 824, 2758,
#         Timestamp('2020-07-28 00:00:00')],
#        [1437, 4201, 3240, 3256, 3051, 2324,
#         Timestamp('2020-07-29 00:00:00')],
#        [2528, 3693, 2535, 3448, 1862, 4900,
#         Timestamp('2020-07-30 00:00:00')],
#        [112, 3064, 4027, 1558, 3002, 3369,
#         Timestamp('2020-07-31 00:00:00')],
#        [1330, 724, 1552, 448, 2943, 3161,
#         Timestamp('2020-08-01 00:00:00')],
#        [2435, 4238, 4219, 3512, 1817, 4880,
#         Timestamp('2020-08-02 00:00:00')],
#        [986, 1219, 12, 52, 1663, 974, Timestamp('2020-08-03 00:00:00')],
#        [512, 4224, 2312, 2640, 3642, 1404,
#         Timestamp('2020-08-04 00:00:00')],
#        [3955, 2438, 2323, 1934, 4116, 3149,
#         Timestamp('2020-08-05 00:00:00')],
#        [1888, 1102, 230, 4677, 4440, 4358,
#         Timestamp('2020-08-06 00:00:00')],
#        [2156, 2115, 1928, 802, 3708, 4998,
#         Timestamp('2020-08-07 00:00:00')],
#        [770, 4605, 3713, 51, 1628, 3642,
#         Timestamp('2020-08-08 00:00:00')],
#        [47, 1949, 851, 971, 1704, 3458, Timestamp('2020-08-09 00:00:00')],
#        [247, 2393, 3115, 453, 1899, 1549,
#         Timestamp('2020-08-10 00:00:00')],
#        [2243, 3578, 1032, 2730, 3886, 546,
#         Timestamp('2020-08-11 00:00:00')],
#        [2414, 1759, 2768, 1200, 2038, 3559,
#         Timestamp('2020-08-12 00:00:00')],
#        [939, 4970, 2060, 2122, 1134, 1537,
#         Timestamp('2020-08-13 00:00:00')],
#        [345, 4258, 1433, 2741, 3659, 688,
#         Timestamp('2020-08-14 00:00:00')],
#        [2174, 449, 2440, 4559, 222, 4328,
#         Timestamp('2020-08-15 00:00:00')],
#        [1809, 3806, 2807, 4041, 4725, 2487,
#         Timestamp('2020-08-16 00:00:00')],
#        [3774, 2471, 421, 1427, 2081, 56,
#         Timestamp('2020-08-17 00:00:00')]], dtype=object)

# %%
dat = data[:,[6,0,1,2,3,4,5]]
dat
# Out:
# array([[Timestamp('2020-05-20 00:00:00'), 4460, 3719, 3527, 228, 2003,
#         4621],
#        [Timestamp('2020-05-21 00:00:00'), 2246, 3718, 3409, 3455, 678,
#         2389],
#        [Timestamp('2020-05-22 00:00:00'), 4434, 3292, 1851, 1717, 2581,
#         1323],
#        [Timestamp('2020-05-23 00:00:00'), 2325, 3077, 3373, 3452, 4729,
#         4021],
#        [Timestamp('2020-05-24 00:00:00'), 189, 669, 4549, 3411, 442,
#         3681],
#        [Timestamp('2020-05-25 00:00:00'), 296, 3794, 3258, 54, 1490,
#         3467],
#        [Timestamp('2020-05-26 00:00:00'), 3847, 4699, 698, 381, 2486,
#         1140],
#        [Timestamp('2020-05-27 00:00:00'), 1304, 1953, 567, 241, 4754,
#         394],
#        [Timestamp('2020-05-28 00:00:00'), 695, 3541, 3748, 2267, 1675,
#         4482],
#        [Timestamp('2020-05-29 00:00:00'), 1655, 2910, 709, 2375, 3681,
#         2909],
#        [Timestamp('2020-05-30 00:00:00'), 3368, 2891, 586, 1455, 535,
#         2783],
#        [Timestamp('2020-05-31 00:00:00'), 4514, 512, 2237, 3621, 704,
#         2422],
#        [Timestamp('2020-06-01 00:00:00'), 4774, 3535, 3489, 2375, 3134,
#         3489],
#        [Timestamp('2020-06-02 00:00:00'), 569, 427, 4568, 2541, 1119,
#         2650],
#        [Timestamp('2020-06-03 00:00:00'), 4866, 2599, 3666, 555, 721,
#         4922],
#        [Timestamp('2020-06-04 00:00:00'), 4106, 72, 2230, 3881, 2812,
#         4169],
#        [Timestamp('2020-06-05 00:00:00'), 4765, 3274, 2278, 3874, 735,
#         998],
#        [Timestamp('2020-06-06 00:00:00'), 241, 2297, 4333, 831, 3566,
#         2355],
#        [Timestamp('2020-06-07 00:00:00'), 4721, 1186, 2023, 3387, 606,
#         3409],
#        [Timestamp('2020-06-08 00:00:00'), 3576, 4388, 4748, 3415, 3987,
#         592],
#        [Timestamp('2020-06-09 00:00:00'), 232, 1668, 1161, 242, 3660,
#         3777],
#        [Timestamp('2020-06-10 00:00:00'), 3899, 4933, 1010, 817, 3960,
#         343],
#        [Timestamp('2020-06-11 00:00:00'), 2539, 858, 1360, 4285, 3382,
#         727],
#        [Timestamp('2020-06-12 00:00:00'), 3979, 4327, 2909, 3157, 4641,
#         509],
#        [Timestamp('2020-06-13 00:00:00'), 1391, 2418, 2117, 645, 2299,
#         3314],
#        [Timestamp('2020-06-14 00:00:00'), 1388, 3865, 2857, 2208, 1978,
#         4342],
#        [Timestamp('2020-06-15 00:00:00'), 955, 1198, 381, 4225, 2422,
#         3213],
#        [Timestamp('2020-06-16 00:00:00'), 4821, 3428, 3546, 2169, 1466,
#         2573],
#        [Timestamp('2020-06-17 00:00:00'), 2543, 1206, 477, 841, 3234,
#         2967],
#        [Timestamp('2020-06-18 00:00:00'), 699, 4412, 2943, 124, 156,
#         4228],
#        [Timestamp('2020-06-19 00:00:00'), 4167, 4147, 1177, 1784, 2456,
#         1432],
#        [Timestamp('2020-06-20 00:00:00'), 2176, 1082, 1539, 274, 370,
#         4121],
#        [Timestamp('2020-06-21 00:00:00'), 1802, 643, 2490, 200, 1646,
#         4066],
#        [Timestamp('2020-06-22 00:00:00'), 4791, 2673, 2738, 4353, 2220,
#         1848],
#        [Timestamp('2020-06-23 00:00:00'), 14, 1561, 3523, 227, 1509, 724],
#        [Timestamp('2020-06-24 00:00:00'), 2080, 2357, 1758, 3308, 2463,
#         4262],
#        [Timestamp('2020-06-25 00:00:00'), 1640, 4223, 2777, 4256, 3382,
#         3645],
#        [Timestamp('2020-06-26 00:00:00'), 2347, 4429, 3793, 1956, 4781,
#         1227],
#        [Timestamp('2020-06-27 00:00:00'), 1471, 3924, 380, 924, 4213,
#         409],
#        [Timestamp('2020-06-28 00:00:00'), 4567, 3613, 4915, 1659, 3621,
#         3377],
#        [Timestamp('2020-06-29 00:00:00'), 3151, 193, 1792, 1953, 193, 45],
#        [Timestamp('2020-06-30 00:00:00'), 1706, 2798, 3556, 1082, 3017,
#         1313],
#        [Timestamp('2020-07-01 00:00:00'), 1655, 2043, 499, 236, 3206,
#         1312],
#        [Timestamp('2020-07-02 00:00:00'), 3498, 171, 966, 3022, 3964,
#         1796],
#        [Timestamp('2020-07-03 00:00:00'), 2465, 1432, 383, 3578, 1883,
#         615],
#        [Timestamp('2020-07-04 00:00:00'), 2698, 1450, 3612, 3753, 210,
#         3240],
#        [Timestamp('2020-07-05 00:00:00'), 945, 4289, 1081, 3672, 4537,
#         4953],
#        [Timestamp('2020-07-06 00:00:00'), 3872, 323, 4411, 1282, 3261,
#         4911],
#        [Timestamp('2020-07-07 00:00:00'), 761, 3992, 4494, 2536, 412,
#         4314],
#        [Timestamp('2020-07-08 00:00:00'), 4698, 2648, 4056, 218, 2827,
#         4244],
#        [Timestamp('2020-07-09 00:00:00'), 3615, 3971, 3387, 3086, 1082,
#         4160],
#        [Timestamp('2020-07-10 00:00:00'), 582, 2697, 227, 3177, 4025,
#         3307],
#        [Timestamp('2020-07-11 00:00:00'), 4244, 3711, 944, 1701, 4539,
#         1574],
#        [Timestamp('2020-07-12 00:00:00'), 816, 4155, 4496, 769, 1630,
#         2285],
#        [Timestamp('2020-07-13 00:00:00'), 4929, 4985, 3470, 2986, 2714,
#         1163],
#        [Timestamp('2020-07-14 00:00:00'), 2946, 1048, 1555, 98, 330,
#         4730],
#        [Timestamp('2020-07-15 00:00:00'), 2772, 1010, 399, 4673, 125,
#         3214],
#        [Timestamp('2020-07-16 00:00:00'), 1007, 1230, 4674, 1122, 289,
#         816],
#        [Timestamp('2020-07-17 00:00:00'), 1147, 3119, 1913, 2743, 3705,
#         3988],
#        [Timestamp('2020-07-18 00:00:00'), 487, 2045, 3807, 4939, 3700,
#         424],
#        [Timestamp('2020-07-19 00:00:00'), 4569, 988, 4868, 2434, 352,
#         3288],
#        [Timestamp('2020-07-20 00:00:00'), 1667, 3656, 3512, 1534, 4598,
#         3609],
#        [Timestamp('2020-07-21 00:00:00'), 4655, 1221, 750, 4819, 2790,
#         898],
#        [Timestamp('2020-07-22 00:00:00'), 2891, 212, 3176, 4444, 3216,
#         4410],
#        [Timestamp('2020-07-23 00:00:00'), 3520, 3069, 958, 4210, 1256,
#         2453],
#        [Timestamp('2020-07-24 00:00:00'), 2174, 2831, 3202, 3637, 1400,
#         2848],
#        [Timestamp('2020-07-25 00:00:00'), 4341, 1504, 203, 2310, 4090,
#         912],
#        [Timestamp('2020-07-26 00:00:00'), 3140, 1205, 4347, 4827, 4852,
#         3536],
#        [Timestamp('2020-07-27 00:00:00'), 4786, 3648, 3669, 3999, 4877,
#         1420],
#        [Timestamp('2020-07-28 00:00:00'), 228, 3089, 4188, 3791, 824,
#         2758],
#        [Timestamp('2020-07-29 00:00:00'), 1437, 4201, 3240, 3256, 3051,
#         2324],
#        [Timestamp('2020-07-30 00:00:00'), 2528, 3693, 2535, 3448, 1862,
#         4900],
#        [Timestamp('2020-07-31 00:00:00'), 112, 3064, 4027, 1558, 3002,
#         3369],
#        [Timestamp('2020-08-01 00:00:00'), 1330, 724, 1552, 448, 2943,
#         3161],
#        [Timestamp('2020-08-02 00:00:00'), 2435, 4238, 4219, 3512, 1817,
#         4880],
#        [Timestamp('2020-08-03 00:00:00'), 986, 1219, 12, 52, 1663, 974],
#        [Timestamp('2020-08-04 00:00:00'), 512, 4224, 2312, 2640, 3642,
#         1404],
#        [Timestamp('2020-08-05 00:00:00'), 3955, 2438, 2323, 1934, 4116,
#         3149],
#        [Timestamp('2020-08-06 00:00:00'), 1888, 1102, 230, 4677, 4440,
#         4358],
#        [Timestamp('2020-08-07 00:00:00'), 2156, 2115, 1928, 802, 3708,
#         4998],
#        [Timestamp('2020-08-08 00:00:00'), 770, 4605, 3713, 51, 1628,
#         3642],
#        [Timestamp('2020-08-09 00:00:00'), 47, 1949, 851, 971, 1704, 3458],
#        [Timestamp('2020-08-10 00:00:00'), 247, 2393, 3115, 453, 1899,
#         1549],
#        [Timestamp('2020-08-11 00:00:00'), 2243, 3578, 1032, 2730, 3886,
#         546],
#        [Timestamp('2020-08-12 00:00:00'), 2414, 1759, 2768, 1200, 2038,
#         3559],
#        [Timestamp('2020-08-13 00:00:00'), 939, 4970, 2060, 2122, 1134,
#         1537],
#        [Timestamp('2020-08-14 00:00:00'), 345, 4258, 1433, 2741, 3659,
#         688],
#        [Timestamp('2020-08-15 00:00:00'), 2174, 449, 2440, 4559, 222,
#         4328],
#        [Timestamp('2020-08-16 00:00:00'), 1809, 3806, 2807, 4041, 4725,
#         2487],
#        [Timestamp('2020-08-17 00:00:00'), 3774, 2471, 421, 1427, 2081,
#         56]], dtype=object)

# %%
d = pd.DataFrame(dat,columns = ['Date','Open','High','Low','Close','Adj Close','Volume'])

d.head()
# Out:
#         Date  Open  High   Low Close Adj Close Volume
# 0 2020-05-20  4460  3719  3527   228      2003   4621
# 1 2020-05-21  2246  3718  3409  3455       678   2389
# 2 2020-05-22  4434  3292  1851  1717      2581   1323
# 3 2020-05-23  2325  3077  3373  3452      4729   4021
# 4 2020-05-24   189   669  4549  3411       442   3681

# %%
d = d.set_index(['Date'])
d
# Out:
#             Open  High   Low Close Adj Close Volume
# Date
# 2020-05-20  4460  3719  3527   228      2003   4621
# 2020-05-21  2246  3718  3409  3455       678   2389
# 2020-05-22  4434  3292  1851  1717      2581   1323
# 2020-05-23  2325  3077  3373  3452      4729   4021
# 2020-05-24   189   669  4549  3411       442   3681
# ...          ...   ...   ...   ...       ...    ...
# 2020-08-13   939  4970  2060  2122      1134   1537
# 2020-08-14   345  4258  1433  2741      3659    688
# 2020-08-15  2174   449  2440  4559       222   4328
# 2020-08-16  1809  3806  2807  4041      4725   2487
# 2020-08-17  3774  2471   421  1427      2081     56
#
# [90 rows x 6 columns]

# %%
d = d.astype(float)
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 90 entries, 2020-05-20 to 2020-08-17
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       90 non-null     float64
#  1   High       90 non-null     float64
#  2   Low        90 non-null     float64
#  3   Close      90 non-null     float64
#  4   Adj Close  90 non-null     float64
#  5   Volume     90 non-null     float64
# dtypes: float64(6)
# memory usage: 4.9 KB

# %%
d.index.name = 'Date'
mpf.plot(d,type='candle')

# %%
d.head()
# Out:
#               Open    High     Low   Close  Adj Close  Volume
# Date
# 2020-05-20  4460.0  3719.0  3527.0   228.0     2003.0  4621.0
# 2020-05-21  2246.0  3718.0  3409.0  3455.0      678.0  2389.0
# 2020-05-22  4434.0  3292.0  1851.0  1717.0     2581.0  1323.0
# 2020-05-23  2325.0  3077.0  3373.0  3452.0     4729.0  4021.0
# 2020-05-24   189.0   669.0  4549.0  3411.0      442.0  3681.0

# %%
mpf.plot(d,type='line')
plt.show()

# %%
mpf.plot(d,type='ohlc',mav = 4)
plt.show()

# %%
mpf.plot(d,type='ohlc',mav = (3,5,7))
plt.show()

# %%
mpf.plot(d,type='ohlc',mav = (3,5,7),volume = True,show_nontrading=True)
plt.show()

# %%
symptoms = ['Coronavirus','Influenza','Pneumonia','Dyspnea']
dates = ['june 28','jul05','jul12','jul19','jul26','Aug02','Aug09','Aug16','Aug21']
symp_per = np.array([
                      [5.2,5.5,5.7,5.6,5.3,5.1,5.0,4.9,5.3],
                      [3.5,4.0,4.3,3.9,3.5,3.2,2.7,2.2,2.0],
                      [1.8,2.2,2.3,2.2,2.1,1.9,1.7,1.4,1.3],
                      [1.0,1.1,1.1,1.0,0.9,0.8,0.8,0.8,0.7]
                    ] )

fig_10, axes_10 = plt.subplots()
im = axes_10.imshow(symp_per,cmap='Wistia')
axes_10.set_xticks(np.arange(len(dates)))
axes_10.set_yticks(np.arange(len(symptoms)))
axes_10.set_xticklabels(dates)
axes_10.set_yticklabels(symptoms)
plt.setp(axes_10.get_xticklabels(),rotation=45,ha='right',rotation_mode='anchor')
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
