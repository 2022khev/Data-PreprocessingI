# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
tips =sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.kdeplot(data=tips,
           x="total_bill",
           )
plt.show()

# %%
iris = sns.load_dataset("iris")

# %%
sns.kdeplot(data=iris)
plt.show()

# %%
sns.kdeplot(data=tips,
           x="total_bill",
           bw_adjust=0.2,
           cut=0)
plt.show()

# %%
sns.kdeplot(data=tips,
           x="total_bill",
           hue="time")
plt.show()

# %%
sns.kdeplot(data=tips,
           x="total_bill",
           hue="time",
           multiple="stack")
plt.show()

# %%
diamond = sns.load_dataset("diamonds")
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.kdeplot(data=diamond,x="price",
           log_scale=True)
plt.show()

# %%
sns.kdeplot(data=tips,
           x="total_bill",
           hue="size")
plt.show()

# %%
sns.kdeplot(data=tips,
           x="total_bill",
           hue="size",
            fill=True,
           common_norm=False,
           palette = 'crest',
           alpha=0.5,
           linewidth=0)
plt.show()

# %%
geyser = sns.load_dataset("geyser")

# %%
geyser
# Out:
#      duration  waiting   kind
# 0       3.600       79   long
# 1       1.800       54  short
# 2       3.333       74   long
# 3       2.283       62  short
# 4       4.533       85   long
# ..        ...      ...    ...
# 267     4.117       81   long
# 268     2.150       46  short
# 269     4.417       90   long
# 270     1.817       46  short
# 271     4.467       74   long
#
# [272 rows x 3 columns]

# %%
sns.kdeplot(data=geyser,x="waiting",y="duration")
# Out:
# <Axes: xlabel='waiting', ylabel='duration'>

# %%
sns.kdeplot(data=geyser,
           x="waiting",
           y="duration",
           hue="kind")
plt.show()

# %%
sns.kdeplot(data=geyser,
           x="waiting",
           y="duration",
           hue="kind",
           fill=True)
plt.show()

# %%
sns.kdeplot(data=geyser,
           x="waiting",
           y="duration",
           hue="kind",
           levels=5,
           thresh=0.2)
plt.show()

# %%
sns.kdeplot(data=geyser,
           x="waiting",
           y="duration",
           hue="kind",
           levels=100,
          thresh=0,
          cmap="mako")
plt.show();
# Out:
# C:\Users\kelvin\.conda\envs\tf\lib\site-packages\seaborn\distributions.py:1138: UserWarning: cmap parameter ignored when using hue mapping.
#   warnings.warn(msg, UserWarning)

# %%
U=pd.DataFrame(
    
    [
    ["25/28","28/35","35/40","40/45","45/50","50/55","55/60","60/65","65+"],
    [60,41,44,41,54,51,28,12,3],
    [0.55,0.9,1.8,2.4,4.7,6.2,4.3,2.45,0.75,24.05]
    ]
        )

# %%
sns.kdeplot(data=U,
           x="total_bill",
           hue="size")
plt.show()
