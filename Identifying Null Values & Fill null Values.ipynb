# %%
import pandas as pd
import numpy as np

# %%
dict1 = {'id':[1,2,3,7,8,9,10,8],
         'names' : ["Elv","Jone","Sil","Mary","Agnes","Esther","Philip","Kentucky"],
    'Age' : [26,27,np.NaN,34,45,67,44,43],
       'state' :['New York','Mexico','Canada','New York','Mexico',np.NAN,'Canada','Mexico'],
        'interest' :[0.5,0.6,0.3,np.NAN,0.45,0.6,0.45,0.45],
         'type':['proprietor',np.NaN,'partnership','proprietor','proprietor',np.NAN,'corporate','corporate']
            }


df1 = pd.DataFrame(dict1)
df1
# Out:
#    id     names   Age     state  interest         type
# 0   1       Elv  26.0  New York      0.50   proprietor
# 1   2      Jone  27.0    Mexico      0.60          NaN
# 2   3       Sil   NaN    Canada      0.30  partnership
# 3   7      Mary  34.0  New York       NaN   proprietor
# 4   8     Agnes  45.0    Mexico      0.45   proprietor
# 5   9    Esther  67.0       NaN      0.60          NaN
# 6  10    Philip  44.0    Canada      0.45    corporate
# 7   8  Kentucky  43.0    Mexico      0.45    corporate

# %%
df1[df1['type'].isna()]
# Out:
#    id   names   Age   state  interest type
# 1   2    Jone  27.0  Mexico       0.6  NaN
# 5   9  Esther  67.0     NaN       0.6  NaN

# %%
df1[df1['type'].isnull()]
# Out:
#    id   names   Age   state  interest type
# 1   2    Jone  27.0  Mexico       0.6  NaN
# 5   9  Esther  67.0     NaN       0.6  NaN

# %%
df1[df1.isna().any(axis=1)]
# Out:
#    id   names   Age     state  interest         type
# 1   2    Jone  27.0    Mexico       0.6          NaN
# 2   3     Sil   NaN    Canada       0.3  partnership
# 3   7    Mary  34.0  New York       NaN   proprietor
# 5   9  Esther  67.0       NaN       0.6          NaN

# %%
df1[df1.isnull().any(axis=1)]
# Out:
#    id   names   Age     state  interest         type
# 1   2    Jone  27.0    Mexico       0.6          NaN
# 2   3     Sil   NaN    Canada       0.3  partnership
# 3   7    Mary  34.0  New York       NaN   proprietor
# 5   9  Esther  67.0       NaN       0.6          NaN

# %%
df =  pd.DataFrame([
                       ('Lewis' ,67,'H1',21),
                       ('Phylis',70,'F3',19),
                       ('Mary',73,'F3',21),
                       ('Steve',pd.NA,'P2',23),
                       ('Edick',67,'H1',21),
                       (pd.NA,78,'F3',pd.NA),
                       ('Carolin',78,pd.NA,pd.NA),
                       (pd.NA,76,'F3',23),
                       ('Euge',67,pd.NA,pd.NA),
                       ('Francis',89,'F3',20)
                   ],
    columns = ('name','marks','department','age') )
df
# Out:
#       name marks department   age
# 0    Lewis    67         H1    21
# 1   Phylis    70         F3    19
# 2     Mary    73         F3    21
# 3    Steve  <NA>         P2    23
# 4    Edick    67         H1    21
# 5     <NA>    78         F3  <NA>
# 6  Carolin    78       <NA>  <NA>
# 7     <NA>    76         F3    23
# 8     Euge    67       <NA>  <NA>
# 9  Francis    89         F3    20

# %% [raw]
# dataframe.fillna(value=None,method=None,axis=None,inplace=None,limit=None,downcast=None)

# %%
df.fillna('No value Available')
# Out:
#                  name               marks          department  \
# 0               Lewis                  67                  H1
# 1              Phylis                  70                  F3
# 2                Mary                  73                  F3
# 3               Steve  No value Available                  P2
# 4               Edick                  67                  H1
# 5  No value Available                  78                  F3
# 6             Carolin                  78  No value Available
# 7  No value Available                  76                  F3
# 8                Euge                  67  No value Available
# 9             Francis                  89                  F3
#
#                   age
# 0                  21
# 1                  19
# 2                  21
# 3                  23
# 4                  21
# 5  No value Available
# 6  No value Available
# 7                  23
# 8  No value Available
# 9                  20

# %%
df['name'].fillna('No name available',inplace=True)

# %%
df.fillna({'name':'No name available', 'marks':'no marks available ','department':'no department','age':'no age available'})
# Out:
#                 name                marks     department               age
# 0              Lewis                   67             H1                21
# 1             Phylis                   70             F3                19
# 2               Mary                   73             F3                21
# 3              Steve  no marks available              P2                23
# 4              Edick                   67             H1                21
# 5  No name available                   78             F3  no age available
# 6            Carolin                   78  no department  no age available
# 7  No name available                   76             F3                23
# 8               Euge                   67  no department  no age available
# 9            Francis                   89             F3                20

# %%
df.fillna(method ='bfill',axis = 0)
# Out:
#                 name  marks department  age
# 0              Lewis     67         H1   21
# 1             Phylis     70         F3   19
# 2               Mary     73         F3   21
# 3              Steve     67         P2   23
# 4              Edick     67         H1   21
# 5  No name available     78         F3   23
# 6            Carolin     78         F3   23
# 7  No name available     76         F3   23
# 8               Euge     67         F3   20
# 9            Francis     89         F3   20

# %%
df.fillna(method='ffill',axis=0)
# Out:
#                 name  marks department  age
# 0              Lewis     67         H1   21
# 1             Phylis     70         F3   19
# 2               Mary     73         F3   21
# 3              Steve     73         P2   23
# 4              Edick     67         H1   21
# 5  No name available     78         F3   21
# 6            Carolin     78         F3   21
# 7  No name available     76         F3   23
# 8               Euge     67         F3   23
# 9            Francis     89         F3   20

# %%
df.fillna(method='backfill',axis=0)
# Out:
#                 name  marks department  age
# 0              Lewis     67         H1   21
# 1             Phylis     70         F3   19
# 2               Mary     73         F3   21
# 3              Steve     67         P2   23
# 4              Edick     67         H1   21
# 5  No name available     78         F3   23
# 6            Carolin     78         F3   23
# 7  No name available     76         F3   23
# 8               Euge     67         F3   20
# 9            Francis     89         F3   20

# %%
df.fillna(method='pad',axis=0)
# Out:
#                 name  marks department  age
# 0              Lewis     67         H1   21
# 1             Phylis     70         F3   19
# 2               Mary     73         F3   21
# 3              Steve     73         P2   23
# 4              Edick     67         H1   21
# 5  No name available     78         F3   21
# 6            Carolin     78         F3   21
# 7  No name available     76         F3   23
# 8               Euge     67         F3   23
# 9            Francis     89         F3   20

# %%
df.fillna(method='ffill',axis=0,limit =2)
# Out:
#                 name  marks department  age
# 0              Lewis     67         H1   21
# 1             Phylis     70         F3   19
# 2               Mary     73         F3   21
# 3              Steve     73         P2   23
# 4              Edick     67         H1   21
# 5  No name available     78         F3   21
# 6            Carolin     78         F3   21
# 7  No name available     76         F3   23
# 8               Euge     67         F3   23
# 9            Francis     89         F3   20

# %%
df.fillna(method='ffill',axis=0,limit=2)
# Out:
#                 name  marks department  age
# 0              Lewis     67         H1   21
# 1             Phylis     70         F3   19
# 2               Mary     73         F3   21
# 3              Steve     73         P2   23
# 4              Edick     67         H1   21
# 5  No name available     78         F3   21
# 6            Carolin     78         F3   21
# 7  No name available     76         F3   23
# 8               Euge     67         F3   23
# 9            Francis     89         F3   20

# %%
df.fillna(0)
# Out:
#                 name  marks department  age
# 0              Lewis     67         H1   21
# 1             Phylis     70         F3   19
# 2               Mary     73         F3   21
# 3              Steve      0         P2   23
# 4              Edick     67         H1   21
# 5  No name available     78         F3    0
# 6            Carolin     78          0    0
# 7  No name available     76         F3   23
# 8               Euge     67          0    0
# 9            Francis     89         F3   20

# %%
df['marks'].fillna(45)
# Out:
# 0    67
# 1    70
# 2    73
# 3    45
# 4    67
# 5    78
# 6    78
# 7    76
# 8    67
# 9    89
# Name: marks, dtype: int64

# %%
values = {'name':'No name available', 
        'marks':np.round(df['marks'].mean(),0),
        'department':'no department',
        'age':np.round(df['age'].mean(),0)
         }
df.fillna(value = values,limit=2)
# Out:
#                 name  marks     department   age
# 0              Lewis   67.0             H1    21
# 1             Phylis   70.0             F3    19
# 2               Mary   73.0             F3    21
# 3              Steve   74.0             P2    23
# 4              Edick   67.0             H1    21
# 5  No name available   78.0             F3  21.0
# 6            Carolin   78.0  no department  21.0
# 7  No name available   76.0             F3    23
# 8               Euge   67.0  no department  <NA>
# 9            Francis   89.0             F3    20

# %%
df.fillna(value= {'name':'No name available', 
                 'marks':np.round(df['marks'].mean(),0),
                'department':'no department',
                'age':np.round(df['age'].mean(),0)
                         }
         )
# Out:
#                 name  marks     department   age
# 0              Lewis   67.0             H1  21.0
# 1             Phylis   70.0             F3  19.0
# 2               Mary   73.0             F3  21.0
# 3              Steve   74.0             P2  23.0
# 4              Edick   67.0             H1  21.0
# 5  No name available   78.0             F3  21.0
# 6            Carolin   78.0  no department  21.0
# 7  No name available   76.0             F3  23.0
# 8               Euge   67.0  no department  21.0
# 9            Francis   89.0             F3  20.0

# %%
# pip install missingno

# %%
df
# Out:
#                 name marks department   age
# 0              Lewis    67         H1    21
# 1             Phylis    70         F3    19
# 2               Mary    73         F3    21
# 3              Steve  <NA>         P2    23
# 4              Edick    67         H1    21
# 5  No name available    78         F3  <NA>
# 6            Carolin    78       <NA>  <NA>
# 7  No name available    76         F3    23
# 8               Euge    67       <NA>  <NA>
# 9            Francis    89         F3    20

# %%
import missingno as msno

# %%
msno.matrix(df);

# %%
msno.heatmap(df);

# %%
msno.dendrogram(df);
